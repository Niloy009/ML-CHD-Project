# %%
import numpy as npy
import pandas as pds
from imblearn.over_sampling import SMOTE
# %matplotlib inline

train_data = pds.read_csv('trainData.csv')
# Out:
# Using TensorFlow backend.

# %%
from collections import Counter
counts = Counter(train_data.TenYearCHD)
counts
# Out:
# Counter({0.0: 2864, 1.0: 528})

# %%
x_inputs = train_data.iloc[:, 0:15]
y_label = train_data.iloc[:, -1]

# %%
sm = SMOTE(random_state=0)
X_resampled, y_resampled = sm.fit_sample(x_inputs, y_label)

# %%
column = x_inputs.columns
cls = ['TenYearCHD']
attri = pds.DataFrame(X_resampled, columns = column)
label = pds.DataFrame(y_resampled, columns = cls)
new_data_smote = pds.concat([attri,label], axis = 1)

# %%
print(Counter(new_data_smote.TenYearCHD))
# Out:
# Counter({0.0: 2864, 1.0: 2864})

# %%
from sklearn.utils import shuffle
new_data_smote = shuffle(new_data_smote)

# %%
new_data_smote.reset_index(inplace=True, drop=True)
new_data_smote.head(20)
# Out:
#         male        age  education  currentSmoker  cigsPerDay  BPMeds  \
# 0   1.000000  47.000000   3.000000       1.000000   25.000000     0.0
# 1   0.552962  53.741472   2.000000       1.000000   20.000000     0.0
# 2   0.048078  52.951922   1.048078       0.000000    0.000000     0.0
# 3   0.000000  48.000000   1.000000       0.000000    0.000000     0.0
# 4   0.328572  44.699993   1.671428       1.000000   34.271442     0.0
# 5   0.000000  53.000000   3.000000       0.000000    0.000000     0.0
# 6   0.000000  59.000000   1.000000       0.000000    0.000000     0.0
# 7   0.660349  40.660349   2.339651       1.000000   16.603490     0.0
# 8   0.000000  44.000000   1.000000       0.000000    0.000000     0.0
# 9   1.000000  47.079205   2.693068       1.000000   16.534658     0.0
# 10  1.000000  66.071959   1.000000       0.000000    0.000000     0.0
# 11  0.000000  48.000000   4.000000       1.000000   17.000000     0.0
# 12  0.000000  46.000000   1.000000       0.000000    0.000000     0.0
# 13  0.175276  64.474173   1.824724       0.000000    0.000000     0.0
# 14  1.000000  63.507078   1.000000       0.821934   24.658023     0.0
# 15  0.000000  51.000000   2.000000       0.000000    0.000000     0.0
# 16  1.000000  58.000000   4.000000       1.000000    5.000000     0.0
# 17  0.326942  65.692231   1.673058       1.000000   20.000000     0.0
# 18  0.000000  43.000000   1.000000       1.000000   15.000000     0.0
# 19  1.000000  48.000000   1.000000       0.000000    0.000000     0.0
#
#     prevalentStroke  prevalentHyp  diabetes     totChol       sysBP  \
# 0               0.0      0.000000       0.0  261.000000  105.000000
# 1               0.0      0.000000       0.0  298.741472  112.276481
# 2               0.0      0.951922       0.0  303.336545  128.336545
# 3               0.0      0.000000       0.0  224.000000  131.000000
# 4               0.0      0.000000       0.0  203.914304  141.357138
# 5               0.0      0.000000       0.0  260.000000  139.000000
# 6               0.0      0.000000       0.0  251.704609  122.599249
# 7               0.0      0.000000       0.0  211.320698  108.943141
# 8               0.0      0.000000       0.0  178.000000  113.000000
# 9               0.0      0.000000       0.0  190.881192  130.227727
# 10              0.0      0.035980       0.0  270.215878  120.251857
# 11              0.0      0.000000       0.0  299.000000  132.000000
# 12              0.0      0.000000       0.0  193.000000  124.500000
# 13              0.0      0.824724       0.0  242.103306  155.262913
# 14              0.0      0.000000       1.0  231.329012  116.369692
# 15              0.0      0.000000       0.0  295.000000  131.000000
# 16              0.0      0.000000       0.0  243.000000  106.000000
# 17              0.0      1.000000       0.0  235.403635  149.749751
# 18              0.0      0.000000       0.0  315.000000  132.500000
# 19              0.0      1.000000       0.0  232.000000  130.500000
#
#         diaBP        BMI  heartRate     glucose  TenYearCHD
# 0   74.000000  20.600000  85.000000   75.000000         0.0
# 1   76.341113  23.012926  77.235188   93.976661         1.0
# 2   90.903844  27.500963  60.192311   76.855767         1.0
# 3   92.000000  26.100000  68.000000   75.400000         0.0
# 4   88.314290  21.491430  80.728558   80.248575         1.0
# 5   80.000000  20.300000  72.000000   76.000000         0.0
# 6   76.164630  27.623237  84.755411  103.738477         1.0
# 7   66.047383  24.928279  77.622443   73.282792         1.0
# 8   78.000000  31.900000  64.000000   74.000000         0.0
# 9   83.693068  23.518808  55.346534   74.613863         1.0
# 10  75.658194  19.341063  64.395776   98.215878         1.0
# 11  81.000000  24.400000  75.000000   70.000000         0.0
# 12  72.000000  26.800000  75.000000   80.000000         0.0
# 13  85.577480  29.672142  91.298898   92.051653         1.0
# 14  65.972285  27.798704  74.643868  208.343167         1.0
# 15  87.000000  24.400000  85.000000   77.000000         0.0
# 16  70.500000  23.700000  60.000000   80.000000         0.0
# 17  87.384462  27.684562  75.269422   87.057520         1.0
# 18  76.500000  31.500000  95.000000   69.300000         0.0
# 19  90.000000  29.100000  85.000000  118.000000         0.0

# %%
columns =(new_data_smote.columns)
x = ''
st = [x+y for y in columns]
st = ','.join([str(elem) for elem in st])
st
# Out:
# 'male,age,education,currentSmoker,cigsPerDay,BPMeds,prevalentStroke,prevalentHyp,diabetes,totChol,sysBP,diaBP,BMI,heartRate,glucose,TenYearCHD'

# %%
#npy.savetxt('trainDataSMOTE.csv', new_data_smote, delimiter=',', fmt='%f', newline='\n', header = st)

# %%
new_data_smote
# Out:
#           male        age  education  currentSmoker  cigsPerDay  BPMeds  \
# 0     1.000000  47.000000   3.000000            1.0   25.000000     0.0
# 1     0.552962  53.741472   2.000000            1.0   20.000000     0.0
# 2     0.048078  52.951922   1.048078            0.0    0.000000     0.0
# 3     0.000000  48.000000   1.000000            0.0    0.000000     0.0
# 4     0.328572  44.699993   1.671428            1.0   34.271442     0.0
# ...        ...        ...        ...            ...         ...     ...
# 5723  0.759455  57.391826   1.240545            1.0   18.797275     0.0
# 5724  0.000000  38.000000   3.000000            0.0    0.000000     0.0
# 5725  1.000000  64.000000   4.000000            0.0    0.000000     0.0
# 5726  1.000000  68.000000   1.000000            1.0   15.000000     0.0
# 5727  1.000000  64.000000   2.000000            0.0    0.000000     0.0
#
#       prevalentStroke  prevalentHyp  diabetes     totChol       sysBP  \
# 0                 0.0      0.000000       0.0  261.000000  105.000000
# 1                 0.0      0.000000       0.0  298.741472  112.276481
# 2                 0.0      0.951922       0.0  303.336545  128.336545
# 3                 0.0      0.000000       0.0  224.000000  131.000000
# 4                 0.0      0.000000       0.0  203.914304  141.357138
# ...               ...           ...       ...         ...         ...
# 5723              0.0      0.000000       0.0  219.089264  114.240545
# 5724              0.0      0.000000       0.0  240.000000  126.500000
# 5725              0.0      0.000000       0.0  273.000000  123.000000
# 5726              0.0      0.000000       0.0  157.000000  106.000000
# 5727              0.0      0.000000       0.0  283.000000  113.000000
#
#           diaBP        BMI  heartRate    glucose  TenYearCHD
# 0     74.000000  20.600000  85.000000  75.000000         0.0
# 1     76.341113  23.012926  77.235188  93.976661         1.0
# 2     90.903844  27.500963  60.192311  76.855767         1.0
# 3     92.000000  26.100000  68.000000  75.400000         0.0
# 4     88.314290  21.491430  80.728558  80.248575         1.0
# ...         ...        ...        ...        ...         ...
# 5723  71.898638  25.731619  67.405449  60.518910         1.0
# 5724  75.500000  24.400000  71.000000  64.000000         0.0
# 5725  73.500000  22.300000  75.000000  84.000000         1.0
# 5726  48.000000  26.700000  65.000000  65.000000         1.0
# 5727  77.000000  22.700000  75.000000  67.000000         0.0
#
# [5728 rows x 16 columns]
